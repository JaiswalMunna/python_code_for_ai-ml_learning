# %%
#TO install seaborn we use 
pip install seaborn
# Out:
#   Cell In[1], line 2
#     pip install seaborn
#         ^
# SyntaxError: invalid syntax

# %%
import seaborn as sns

# %%
df=sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
len(df)
# Out:
# 150

# %%
df.head(150)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df.species.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
sns.kdeplot(df['sepal_length'],shade=True)
# Out:
# C:\Users\munna\AppData\Local\Temp\ipykernel_20928\4098833004.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['sepal_length'],shade=True)
# <Axes: xlabel='sepal_length', ylabel='Density'>

# %%
sns.boxplot(df['petal_length'])
# Out:
# <Axes: ylabel='petal_length'>

# %%
sns.boxplot(df['petal_length'],df['petal_width'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sns.boxplot(df['petal_length'],df['petal_width'])
#
# TypeError: boxplot() takes from 0 to 1 positional arguments but 2 were given

# %%
#KDE: Kernel desnity estimation
for col in ['sepal_length','sepal_width','petal_length','petal_width']:
    sns.kdeplot(df[col],shade=True)
# Out:
# C:\Users\munna\AppData\Local\Temp\ipykernel_20928\2541461480.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col],shade=True)
# C:\Users\munna\AppData\Local\Temp\ipykernel_20928\2541461480.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col],shade=True)
# C:\Users\munna\AppData\Local\Temp\ipykernel_20928\2541461480.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col],shade=True)
# C:\Users\munna\AppData\Local\Temp\ipykernel_20928\2541461480.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[col],shade=True)
