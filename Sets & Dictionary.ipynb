# %%
s={"ram",1,1.5,"hari","ram"}
s
type(s)
# Out:
# set

# %%
list=['a','b','c','a','a','c','d','e']
s=set(list)
s
# Out:
# {'a', 'b', 'c', 'd', 'e'}

# %%
print(type(s))
# Out:
# <class 'set'>

# %%
s.add("hi")

# %%
print(s)
# Out:
# {'d', 'a', 'c', 'hi', 'e', 'b'}

# %%
s.remove("a")

# %%
print(s)
print(len(s))
# Out:
# {'d', 'c', 'e', 'b'}
# 4

# %%
#Dictionary

# %%
d={"Nepal":"rupees","India":"rupee","USA":"dollar"}

# %%
print(d)
# Out:
# {'Nepal': 'rupees', 'India': 'rupee', 'USA': 'dollar'}

# %%
print(type(d))
# Out:
# <class 'dict'>

# %%
#accessinf using key
print(d["Nepal"])
# Out:
# rupees

# %%
d["Nepal"]="INR"

# %%
print(d)
# Out:
# {'Nepal': 'INR', 'India': 'rupee', 'USA': 'dollar'}

# %%
#inserting new key-value
d={"Nepal":"rupees","India":"rupee","USA":"dollar"}
d["Japan"]="YEN"
print(d)
print(len(d))
# Out:
# {'Nepal': 'rupees', 'India': 'rupee', 'USA': 'dollar', 'Japan': 'YEN'}
# 4

# %%
#deleting key-value pair
del d["Japan"]

# %%
print(d)
# Out:
# {'Nepal': 'rupees', 'India': 'rupee', 'USA': 'dollar'}
