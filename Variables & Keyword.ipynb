# %%
a=5
print(a)
# Out:
# 5

# %%
type(a)
# Out:
# int

# %%
a='5'
print(type(a))
# Out:
# <class 'str'>

# %%
#print, type(), return, def ---> everything they are keyword. there are many more keywords in python
