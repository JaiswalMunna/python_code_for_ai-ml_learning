# %% [markdown]
# File Handling

# %% [markdown]
# Reading a file

# %%
file = open('test.txt','r')

# %%
for lines in file:
    print(lines)
# Out:
# Hello, My name is Munna Kumar Chaudhary.
#
# I am beginner here to learn AI/ML course from udemy.

# %%
print(file.read())
# Out:
# Hello, My name is Munna Kumar Chaudhary.
# I am beginner here to learn AI/ML course from udemy.

# %%
print(file.read(15))
# Out:
# Hello, My name

# %%
print(file.readline())
# Out:
# I am beginner here to learn AI/ML course from udemy.

# %% [markdown]
# Writing a file

# %%
file = open('test.txt','w')
file.write("This is a write operations.\n")
file.write("Operation perform successsfully. Thank you for choosing us.")
file.close()

# %%
file = open('test.txt','r')
print(file.read())
# Out:
# This is a write operations.
# Operation perform successsfully. Thank you for choosing us.

# %% [markdown]
# Append Operation

# %%
with open('test.txt','a') as file:
    file.write("\nAnother line is here.\n which is append method.")

# %%
file=open('test.txt','r')
#for line in file:
 #   print(line)

print(file.read())
# Out:
# This is a write operations.
# Operation perform successsfully. Thank you for choosing us.Another line is here.
#  which is append method.
# Another line is here.
#  which is append method.

# %% [markdown]
# Pandas Operation

# %%
import pandas as pd

# %%
df=pd.read_csv('StudentsPerformance.csv')

# %%
df.head(5)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
