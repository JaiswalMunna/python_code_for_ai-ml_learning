# %%
name="Munna"
print(name)
type(name)
# Out:
# Munna
# str

# %%
name=input("Enter your name")
myname=input("Enter another name")
print("Welcome",name,"\nHi", name,"\nHow are you",name, "\nMy name is ", myname, "\nIts nice to meet you.")
# Out:
# Enter your name munna
# Enter another name mike
# Welcome munna
# Hi munna
# How are you munna
# My name is  mike
# Its nice to meet you.

# %%
accuracy=91.3
print(accuracy)
print(type(accuracy))
# Out:
# 91.3
# <class 'float'>

# %%
percentage=91.8
print(percentage)
print(type(percentage))
# Out:
# 91.8
# <class 'float'>

# %%
correct_accuracy=int(accuracy)
print(correct_accuracy)
print(type(correct_accuracy))
# Out:
# 91
# <class 'int'>

# %%
string_var='ASDFG'

# %%
type(string_var)
# Out:
# str

# %%
int_var=int(string_var)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 int_var=int(string_var)
#
# ValueError: invalid literal for int() with base 10: 'ASDFG'

# %%
float_var=float(string_var)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 float_var=float(string_var)
#
# ValueError: could not convert string to float: 'ASDFG'

# %%
a=10
b=5

# %%
a+b
# Out:
# 15

# %%
a-b
# Out:
# 5

# %%
a*b
# Out:
# 50

# %%
a/b
# Out:
# 2.0

# %%
c=int(a/b)

# %%
print(c)
# Out:
# 2

# %%
a**b   #something to the power of something a**b will be a to the power to the b. like here is a is 10 and b is 5 then 10^5
# Out:
# 100000

# %%
a//b
# Out:
# 2

# %%
a//b  --> Floor division
floor 
ceiling
# Out:
#   Cell In[26], line 1
#     a//b  --> Floor division
#            ^
# SyntaxError: invalid syntax

# %%
a=10
b=2
a/b  #this is normal division
# Out:
# 5

# %%
a//b  #this is floor division like 2.something will be 2
    #and in ceiling value for 2.something that will be 3
# Out:
# 5

# %%
a%b #this is modulus operation like if we divide and number then the remainder will be here
# Out:
# 0

# %%
#BODMAS
print((4*5)-9+6/7)   #20-9+6/7
                     #20-9+0.8571
                     #20.8571-9  #11.8571
# Out:
# 11.857142857142858
