# %%
tuples=("mango",1,2.5)
print(tuples)
print(type(tuples))
# Out:
# ('mango', 1, 2.5)
# <class 'tuple'>

# %%
t=(1,2,3,(4,5))
print(t)
print(type(t))
# Out:
# (1, 2, 3, (4, 5))
# <class 'tuple'>

# %%
t=(1,2,3,(4,5))
print(t[3])
print(type(t[3]))
print((t[3][1]))
# Out:
# (4, 5)
# <class 'tuple'>
# 5

# %%
t=("delhi",1,1.54)
print(t)
print(type(t))
# Out:
# ('delhi', 1, 1.54)
# <class 'tuple'>

# %%
t=("delhi",1,1.54,"python","machine learning")
print(t)
# Out:
# ('delhi', 1, 1.54, 'python', 'machine learning')

# %%
print(t[2:])
# Out:
# (1.54, 'python', 'machine learning')

# %%
#min, max and sum function
t=(1,5,7,9,2,5,4)
sum(t)
# Out:
# 33

# %%
max(t)
# Out:
# 9

# %%
min(t)
# Out:
# 1

# %%
t=("Helo","welcome",5,10,"world","of","analytics")
print(t)
# Out:
# ('Helo', 'welcome', 5, 10, 'world', 'of', 'analytics')

# %%
t[0:2]
# Out:
# ('Helo', 'welcome')

# %%
t[4:]
# Out:
# ('world', 'of', 'analytics')

# %%
t[0:2]+("to","the")+t[4:]
# Out:
# ('Helo', 'welcome', 'to', 'the', 'world', 'of', 'analytics')
